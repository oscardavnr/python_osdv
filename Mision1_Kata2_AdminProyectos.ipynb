# %% [markdown]
# # Crear un entorno virtual

# %% [markdown]
# Como desarrollador, es probable que crees muchos programas en una sola máquina. Esos programas también se pueden usar en otras máquinas. Sin embargo, algunas de estas máquinas pueden tener versiones de Python instaladas que no son lo que espera. O bien, pueden tener bibliotecas instaladas que son de versión inferior o superior a las que necesita su programa.
#
# Entonces, ¿Qué hacer? Debes encontrar una manera de que tu programa funcione de forma aislada, para que no moleste lo que está instalado en la máquina de destino. También debes asegurarte de que una máquina no deshabilite tu programa porque tiene instalada la versión incorrecta de Python o la versión de la biblioteca.
#
# Un entorno virtual es una copia autónoma de todo lo necesario para ejecutar el programa. Esto incluye el intérprete de Python y cualquier biblioteca que su programa necesite. Mediante el uso de un entorno virtual, puedes asegurarte de que tu programa tendrá acceso a las versiones y recursos correctos para ejecutarse correctamente.

# %% [markdown]
# ### A continuación, mi desarrollo creando el entorno desde windows

# %% [markdown]
# Microsoft Windows [Versión 10.0.19044.1526]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\oscar>python3 -m venv env
# No se encontr¾ Python; ejecuta sin argumentos para instalar desde Microsoft Store o deshabilita este acceso directo en Configuraci¾n > Administrar alias de ejecuci¾n de la aplicaci¾n.
#
# C:\Users\oscar>pyhton3
# "pyhton3" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
#
# C:\Users\oscar>pyhton
# "pyhton" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
#
# C:\Users\oscar>Py
# Python 3.10.2 (tags/v3.10.2:a58ebcc, Jan 17 2022, 14:12:15) [MSC v.1929 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>> exit()
#
# C:\Users\oscar>py -m venv env
#
# C:\Users\oscar>
# C:\Users\oscar>rrrr
# "rrrr" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
#
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>
# C:\Users\oscar>py -m venv env
#
# C:\Users\oscar>env\bin\activate
# El sistema no puede encontrar la ruta especificada.
#
# C:\Users\oscar>source env\bin\activate
# "source" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
#
# C:\Users\oscar>env\Scripts\activate
#
# (env) C:\Users\oscar>pip freeze
#
# (env) C:\Users\oscar>pip install
# ERROR: You must give at least one requirement to install (see "pip help install")
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\oscar\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\Users\oscar>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\oscar\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\Users\oscar>pip freeze
# python-dateutil==2.8.2
# six==1.16.0
#
# (env) C:\Users\oscar>deactivate
# C:\Users\oscar>

# %% [markdown]
# @oscardavnr
# LaunchX
